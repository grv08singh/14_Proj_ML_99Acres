# %%
import numpy as np
import pandas as pd
df = pd.read_csv("data/07_flats_EDA.csv")

# %%
df['sector'].unique()
# Out:
# <ArrowStringArray>
# [  'sector 7',   'sector 3',  'sector 33',  'sector 61',  'sector 92',
#  'sector 102', 'sector 104',  'sector 88',  'sector 78',  'sector 81',
#   'sector 79',  'sector 90', 'sector 108',  'sector 62',  'sector 89',
#  'sector 113',  'sector 65',  'sector 48',  'sector 37', 'sector 110',
#   'sector 43',  'sector 68', 'sector 109', 'sector 106',  'sector 82',
#   'sector 85',  'sector 28',  'sector 10',   'sector 1',  'sector 21',
#   'sector 84',  'sector 71',  'sector 77',  'sector 67',  'sector 57',
#   'sector 95',  'sector 99', 'sector 103',  'sector 49',  'sector 30',
#   'sector 86',  'sector 66',  'sector 15',   'sector 4',  'sector 22',
#   'sector 63',  'sector 52', 'sector 107',  'sector 12',   'sector 9',
#   'sector 17',   'sector 2',  'sector 91',  'sector 70',  'sector 47',
#   'sector 54', 'sector 111',  'sector 41',  'sector 73',  'sector 36',
#   'sector 56',  'sector 83',  'sector 53',  'sector 72',  'sector 69',
# ...

# %%
df.columns
# Out:
# Index(['area_sqm', 'bedroom', 'bathroom', 'balcony', 'addl_room', 'sector',
#        'landmark_count', 'has_hospital_or_clinic', 'has_police_stn',
#        'has_fire_stn', 'has_mall', 'has_market', 'has_park', 'has_bank_or_atm',
#        'has_institute', 'has_airport', 'has_rly_stn', 'has_metro_stn',
#        'has_expy', 'has_petrol_pump', 'has_hotel', 'has_temple_or_church',
#        'has_famous_chowk', 'has_club', 'has_stadium', 'has_restro_cafe',
#        'area_type', 'floor_rise', 'age', 'society', 'city', 'price_cr'],
#       dtype='str')

# %%
df['area_type'].mode()
# Out:
# 0    super built up
# Name: area_type, dtype: str

# %%
df['city'].mode()
# Out:
# 0    gurgaon
# Name: city, dtype: str

# %%
bedroom=1
df[df['bedroom'] == bedroom]['area_sqm'].min(), df[df['bedroom'] == bedroom]['area_sqm'].max()
# Out:
# (np.float64(23.23), np.float64(111.28))

# %%
bedroom=7
df[df['bedroom'] == bedroom]['bathroom'].mode()
# Out:
# Series([], Name: bathroom, dtype: float64)
